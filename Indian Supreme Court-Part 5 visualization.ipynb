# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle 
import seaborn as sns

# %%
year_df=pd.read_pickle('year_df.pickle')

# %%
year_df=year_df.T

# %%
year_df.columns=['general','election','rape','marriage fraud','estate','employee-employer relation','robbery','Obscenity','Bank Money','Sudden death','murder','Committe administration','justice','family conflicts','Nationality','insurance','Road Safety','Linching','Land Disputes','Tax']

# %%
year_df
# Out:
#       general  election   rape  marriage fraud  estate  \
# year
# 2001    180.0      98.0   63.0           111.0    68.0
# 2002    196.0     254.0   67.0            77.0   125.0
# 2003    212.0     205.0  101.0            85.0   163.0
# 2004    213.0     157.0   73.0            70.0   109.0
# 2005    164.0      94.0   45.0            83.0    87.0
# 2006    213.0     121.0   52.0           113.0    74.0
# 2007    266.0     170.0   86.0           118.0   109.0
# 2008    720.0     284.0  136.0           201.0   128.0
# 2009    551.0     301.0  112.0           130.0    52.0
# 2010    326.0     154.0  106.0            82.0    54.0
# 2011    283.0     178.0  107.0            53.0    60.0
# 2012    213.0     129.0   43.0            45.0    23.0
# 2013    248.0     158.0   60.0            76.0    15.0
# 2014    144.0     118.0   57.0            58.0    17.0
# 2015    153.0     108.0   46.0            70.0    56.0
# 2016     54.0      17.0   22.0             9.0     4.0
#
# ...

# %%
year_df.isna().sum()
# Out:
# general                       0
# election                      0
# rape                          0
# marriage fraud                0
# estate                        0
# employee-employer relation    0
# robbery                       0
# Obscenity                     0
# Bank Money                    0
# Sudden death                  0
# murder                        0
# Committe administration       0
# justice                       0
# family conflicts              0
# Nationality                   0
# insurance                     1
# Road Safety                   0
# Linching                      0
# Land Disputes                 1
# Tax                           0
# dtype: int64

# %%
year_df.fillna(0,inplace=True)

# %%
sns.set()
year_df.plot(kind='bar', stacked=True, figsize = (20,10),fontsize=20)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
year_df.to_csv('year_df.csv')

# %%
year_df.to_excel('year_df.xlsx')
